# %% [markdown]
# For Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! ls
# Out:
# drive  sample_data

# %%
# %cd drive/MyDrive/Colab Notebooks/MLProject/multi-step-forecasting-rnn
# Out:
# /content/drive/MyDrive/Colab Notebooks/MLProject/multi-step-forecasting-rnn

# %%
# !git branch
# Out:
#   main
# * ozgur-branch

# %%
# !git add .

# %%
# !git commit -m "Tensorflow import and more functionality for colab added"

# %% [markdown]
# End of Colab Code

# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
print(tf.__version__)
# Out:
# 2.14.0

# %%
day_ds = pd.read_csv('data/day.csv')
hour_ds = pd.read_csv('data/hour.csv')

# %%
# Out:
# 2.14.0
